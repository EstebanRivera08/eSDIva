# %% [markdown]
# # 1. Notebook kernel setup

# %% [markdown]
# After cloning repository at https://github.com/EstebanRivera08/PySonoGen, and the uv package, go on terminal to the location of the repository and run the following command to install the required packages:
#
# `` uv run pycalib ``
#
# To run these jupyter notebooks, the .venv environment of the project must be used as kernel.
# To do so, from the repository path, you can run.
#
# `` uv run -m ipykernel install --user --name=.venv --display-name "PySonoGen (.venv)" ``
#
# This will create a jupyter kernel named 'PySonoGen (.venv)', that one can then select as kernel
# of the notebook.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pyvista as pv

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 2. Characterization of Matrix Transducer

# %%
import pysonogen.transducers as Transducers
from pysonogen import pyfield
import pysonogen

print(Transducers.available_transducers())

Zeus_Matrix = Transducers.Zeus_Matrix()
# Out:
# ['LinearArrayTransducer', 'MatrixArrayTransducer', 'Domino', 'Zeus_Matrix']
# MatrixArrayTransducer initialized with 3025 elements and 12100 patches.
# Transducer initialized in 0.0590 seconds.

# %%
# Focalization spot
focus_mm = np.array([0, 0, 5])  # mm [x, y, z]

field_info_mm = {
    "x_extent": [-0.3 + focus_mm[0], 0.3 + focus_mm[0]],
    "y_extent": [-0.3 + focus_mm[1], 0.3 + focus_mm[1]],
    "z_extent": [-1.5 + focus_mm[2], 1.5 + focus_mm[2]],
    "dx": 0.025,
    "dy": 0.025,
    "dz": 0.1,
}

# %%
F_over_D = 2.0
print(f"F_over_D: {F_over_D}")

delays = Zeus_Matrix.compute_delays(focus_mm=focus_mm, plot=True)

apodization = Zeus_Matrix.compute_apodization(
    focus_mm=focus_mm, F_over_D=F_over_D, apodization_type="circular", plot=True
)
# Out:
# F_over_D: 2.0
# ...

# %%
run_loop = False
folder = r'..\pressure_fields'
list_FD = [0.1, 0.35, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0]
focal_lengths = np.zeros((len(list_FD), 3))
count = 0

if run_loop:

    for F_over_D in list_FD:
        print(f"F_over_D: {F_over_D}")

        delays = Zeus_Matrix.compute_delays(focus_mm=focus_mm, plot=False)

        apodization = Zeus_Matrix.compute_apodization(
            focus_mm=focus_mm, F_over_D=F_over_D, apodization_type="circular", plot=False
        )

        Matrix_field = pyfield.PyField(Zeus_Matrix)

        pressure_field, x, y, z = Matrix_field.compute_pressure_field(field_info_mm, inplace = False)

        pysonogen.plot_field_planes(
        pressure_field, x, y, z)

        nx, ny, nz = pressure_field.shape
        print(f"Pressure field shape: {nx} x {ny} x {nz}")

        mask3D = pressure_field > 0.5 * np.max(pressure_field)
        
        focal_lx = np.sum(mask3D[:, ny//2+1, nz//2+1]) * (x[1] - x[0])
        focal_ly = np.sum(mask3D[nx//2+1, :, nz//2+1]) * (y[1] - y[0])
        focal_lz = np.sum(mask3D[nx//2+1, ny//2+1, :]) * (z[1] - z[0])
        print(f"Focal length in (x, y, z): ({focal_lx:.2f}, {focal_ly:.2f}, {focal_lz:.2f}) mm")
        focal_lengths[count, :] = [focal_lx, focal_ly, focal_lz]

        # suppose pressure, x, y, z are your arrays
        filename = f'/Zeus_field_{str(F_over_D).replace(".", "-")}.npz'
        np.savez_compressed(folder + filename,
                        pressure=pressure_field,
                        x=x,
                        y=y,
                        z=z,
                        F_over_D=F_over_D)
        print(f"Saved field to {folder + filename}")
        
        count += 1
# Out:
# F_over_D: 0.1
# ...
# Successfully initialized PyField with
#  MatrixArrayTransducer(n_elem_x=55, n_elem_y=55, el_w_mm=0.29, kerf_x_mm=0.010000000000000009, kerf_y_mm=0.010000000000000009, no_sub_x=2, no_sub_y=2, fc_Hz=10000000.0)
# Computing SIR for 16399 points and 12100 patches...
# Events patch - field points computed in: 0.3440 seconds.
# Accumulation of events elapsed in: 38.6154 seconds.
# SIR computed in 38.9609 seconds.
# Computing pressure field...
# Performing FFT...
# Frequency searched: 10000000.0 Hz. Found: 9970674.486803519 Hz
# Taking slice x_ind, y_ind, z_ind = 12/23, 12/23, 16/31
# Pressure field shape: 23 x 23 x 31
# Focal length in (x, y, z): (0.08, 0.08, 0.60) mm
# Saved field to ..\pressure_fields/Zeus_field_0-1.npz
# F_over_D: 0.35
# ...
# Successfully initialized PyField with
#  MatrixArrayTransducer(n_elem_x=55, n_elem_y=55, el_w_mm=0.29, kerf_x_mm=0.010000000000000009, kerf_y_mm=0.010000000000000009, no_sub_x=2, no_sub_y=2, fc_Hz=10000000.0)
# ...

# %% [markdown]
# The way we compute the radio of active elements is
#
# $ N_{act} \approx (\frac{F}{d})^{-1} \frac{F}{pitch} tan(\theta_{max}) $

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
fig.suptitle('Focal length vs F_over_D')

axs[0].plot(list_FD, focal_lengths[:, 0], '--r', label='Focal length in x')
axs[0].plot(list_FD, focal_lengths[:, 1], '-k', label='Focal length in y')
axs[0].set_xlabel('F_over_D')
axs[0].set_ylabel('Focal length (mm)')
axs[0].legend()
axs[0].grid()

axs[1].plot(list_FD, focal_lengths[:, 2], 'b', label='Focal length in z')
axs[1].set_xlabel('F_over_D')
axs[1].set_ylabel('Focal length (mm)')
axs[1].legend()
axs[1].grid()

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# The only reliable results are over 0.75 of F/D. Thus, the closest two different focals spots on a z-plane is $\Delta x$, so if we want to do an aproximation of a line it should be by trying focalization at three positions on the plane. Let's suppose:
#
# $r_{f1} = ()

# %%
import pysonogen as pysonogen
F_over_D = 1.0

filename = f'/Zeus_field_{str(F_over_D).replace(".", "-")}.npz'
data = np.load(folder + filename)

pressure_field = data['pressure']
x = data['x']
y = data['y']
z = data['z']

nx, ny, nz = pressure_field.shape
x_profile = pressure_field[nx//2+1, :, nz//2+1].squeeze()


pysonogen.plot_field_planes(
pressure_field, x, y, z)

def focal_profile(y_val, shift = 0):
	return np.interp(y_val, y - shift, x_profile)
# Out:
# Taking slice x_ind, y_ind, z_ind = 12/23, 12/23, 16/31

# %%
num_focal = 1
num_focal = num_focal if num_focal % 2 == 1 else num_focal + 1

# distance = y[np.argmin(np.abs(x_profile -  0.5 * np.max(x_profile)))].max()*2
distance = 9/num_focal 
print(f"Distance to focal point: {distance:.2f} mm")

radial_axis = np.linspace(-1.5, 1.5, 100)
focales = np.zeros((num_focal, len(radial_axis)))
for idx, i in enumerate(np.linspace(-num_focal//2+1, num_focal//2, num_focal)):
    focales[idx, :] = focal_profile(radial_axis, i * distance)
# Out:
# Distance to focal point: 9.00 mm

# %% [markdown]
# # 3. Logic Conception

# %%
nx_elem = 55
n_elem = np.linspace(1, nx_elem, nx_elem)

# %%
delay_profile = np.zeros((num_focal,nx_elem))
apod_profile  = np.zeros((num_focal,nx_elem))
delay_surf    = np.zeros((num_focal, nx_elem, nx_elem))
apod_surf     = np.zeros((num_focal, nx_elem, nx_elem))

for idx, i in enumerate(np.linspace(-num_focal//2+1, num_focal//2, num_focal)):
    focus_mm = np.array([0 + i * distance, 0, 5])  # mm [x, y, z]
    print(f"Focus shifted to: {focus_mm}")

    # Compute delays and apodization
    delays = Zeus_Matrix.compute_delays(focus_mm=focus_mm, plot=False)

    apodization = Zeus_Matrix.compute_apodization(
        focus_mm=focus_mm, F_over_D=F_over_D, apodization_type="circular", plot=False
    )
    delay_surf[idx,:,:] = delays.reshape([nx_elem,nx_elem])
    apod_surf[idx,:,:] = apodization.reshape([nx_elem,nx_elem])
    delay_profile[idx,:] = delays.reshape([nx_elem,nx_elem])[nx_elem//2+1,:]
    apod_profile[idx,:] = apodization.reshape([nx_elem,nx_elem])[nx_elem//2+1,:]
# Out:
# Focus shifted to: [0. 0. 5.]
# ...

# %%
acum_profile_delay = np.max(delay_profile, axis=0)

plt.figure(figsize=(10, 4))
for i in range(num_focal):
    plt.plot(n_elem, delay_profile[i,:], '--', label='Apodization profile at x=0')

plt.plot(n_elem,acum_profile_delay, 'k', label='Apodization profile at x=0')
plt.xlabel('Element number')
plt.ylabel('Delay (us)')
plt.grid()
plt.legend()
plt.show()
plt.close()

# %%
# Compute accumulated delay and apodization surfaces
accumulated_delay = np.max(delay_surf, axis = 0)
accumulated_apod = apod_surf.sum(axis=0)
accumulated_apod[accumulated_apod > 1] = 1  # Normalize apodization values to be between 0 and 1

# %%
Zeus_Matrix = pysonogen.transducers.Zeus_Matrix()

Zeus_Matrix.set_apodization(accumulated_apod.flatten())
Zeus_Matrix.set_delays(accumulated_delay.flatten())
Zeus_Matrix.plot_apodization()
Zeus_Matrix.plot_delays()
# Out:
# MatrixArrayTransducer initialized with 3025 elements and 12100 patches.
# Transducer initialized in 0.0582 seconds.

# %%
# Focalization spot
focus_mm = np.array([0, 0, 5])  # mm [x, y, z]

field_info_mm = {
    "x_extent": [-(1+distance*(num_focal-1)/2) + focus_mm[0], (1+distance*(num_focal-1)/2) + focus_mm[0]],
    "y_extent": [-0.25 + focus_mm[1], 0.25 + focus_mm[1]],
    "z_extent": [-1.5 + focus_mm[2], 1.5 + focus_mm[2]],
    "dx": 0.1,
    "dy": 0.1,
    "dz": 0.1,
}

# %%
Matrix_field = pyfield.PyField(Zeus_Matrix)

pressure_field, x2, y2, z2 = Matrix_field.compute_pressure_field(field_info_mm, inplace = False)
# Out:
# Successfully initialized PyField with
#  MatrixArrayTransducer(n_elem_x=55, n_elem_y=55, el_w_mm=0.29, kerf_x_mm=0.010000000000000009, kerf_y_mm=0.010000000000000009, no_sub_x=2, no_sub_y=2, fc_Hz=10000000.0)
# Computing SIR for 15655 points and 12100 patches...
# Events patch - field points computed in: 0.2611 seconds.
# Accumulation of events elapsed in: 35.9595 seconds.
# SIR computed in 36.2216 seconds.
# Computing pressure field...
# Performing FFT...
# Frequency searched: 10000000.0 Hz. Found: 9965803.61504641 Hz

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

y0 = int(np.floor(y2.shape[0] / 2))
z0 = int(np.floor(z2.shape[0] / 2))

XZ_plane = pressure_field[:, y0, :].squeeze()
XY_plane = pressure_field[:, :, z0].squeeze()

Dx, Dy, Dz = x2.max()-x2.min(), y2.max()-y2.min(), z2.max()-z2.min()
ratios = [Dx/Dz, Dx/Dy, Dy/Dz]
ratios = ratios / np.sum(ratios)

fig = plt.figure(figsize=(9, 4))
gs = gridspec.GridSpec(2, 1, height_ratios = [1, 0.2])  # Two columns, equal width

ax0 = fig.add_subplot(gs[0])
im0 = ax0.imshow(XZ_plane.T, cmap='jet', extent=[x2.min(), x2.max(), z2.min(), z2.max()], interpolation='bilinear')
ax0.set_xlabel("X (mm)")
ax0.set_ylabel("Z (mm)")
ax0.set_title("XZ Plane")
plt.colorbar(im0, ax=ax0, label='Pressure (Pa)')

ax1 = fig.add_subplot(gs[1])
im1 = ax1.imshow(XY_plane.T, cmap='jet', extent=[x2.min(), x2.max(), y2.min(), y2.max()], interpolation='bilinear')
ax1.set_xlabel("X (mm)")
ax1.set_ylabel("Y (mm)")
ax1.set_title("XY Plane")

plt.tight_layout()
plt.show()

# %%
from pysonogen.functions import add_transducer_mesh

pressure_plotter, pressure_vol_mesh = pysonogen.plot_pressure_field(pressure_field,
                               x, y, z, notebook = False, return_mesh = True, window_size = [620, 780])

pressure_plotter = add_transducer_mesh(Zeus_Matrix.get_mesh(), 
                        plotter=pressure_plotter, lighting=True, ambient=1)
pressure_plotter.show()  # Add this parameter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 from pysonogen.functions import add_transducer_mesh
# ----> 3 pressure_plotter, pressure_vol_mesh = pysonogen.plot_pressure_field(pressure_field,
#       4                                x, y, z, notebook = False, return_mesh = True, window_size = [620, 780])
#       6 pressure_plotter = add_transducer_mesh(Zeus_Matrix.get_mesh(),
#       7                         plotter=pressure_plotter, lighting=True, ambient=1)
#       8 pressure_plotter.show()  # Add this parameter
#
# NameError: name 'pressure_field' is not defined

# %% [markdown]
# # 4. PyTorch Implementation

# %% [markdown]
# ## 4.1 Creation of torch model

# %%
import numpy as np
import matplotlib.pyplot as plt

# from torch_test import TorchField, create_simulation_grid
import torch
import pysonogen
from PyFieldTorch import PyFieldTorch
from TorchFieldv2 import TorchFieldv2
from TorchField import TorchField
from pysonogen import pyfield

# %load_ext autoreload
# %autoreload 2

print(torch.__version__)

use_cuda = True  # Set to False if you want to run on CPU
device_number = 0  # if you have multiple GPUs
if torch.cuda.is_available() and use_cuda:
    print(f"Using GPU: {torch.cuda.get_device_name(device_number)}")
    device = torch.device(f"cuda:{device_number}")
else:
    print("Running on CPU. May be slow.")
    device = torch.device("cpu")

# device = torch.device("cpu")  # Force CPU for this example
# Out:
# 2.6.0+cu126
# Using GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
# Focalization spot
focus_mm = np.array([0, 0, 8])  # mm [x, y, z]
F_over_D = 1

# Create transducer with elevation focus
n_elements = 128
pitch_mm = 0.11
element_width_mm = 0.108
element_height_mm = 1.5
elevation_focus_mm = 0  # mm
tx_freq = 12.5  # MHz

c = 1540.0  # speed of sound in soft tissue (m/s)
tx = pysonogen.transducers.LinearArrayTransducer(
    n_elements         = n_elements,
    element_width_mm   = element_width_mm,
    element_height_mm  = element_height_mm,
    elevation_focus_mm = elevation_focus_mm,
    kerf_mm            = pitch_mm - element_width_mm,
    no_sub_x           = 1,
    no_sub_y           = 2,
    frequency_Hz       = tx_freq*1e6,  # MHz
)

# Focalization spot

field_info_mm = {
    "x_extent": [0, 0],
    "y_extent": [0, 0],
    "z_extent": [focus_mm[2],focus_mm[2]],
    "dx": 0,
    "dy": 0,
    "dz": 0,
}
print(f"Field info: {field_info_mm}")


# apod = np.zeros(n_elements)
# delta = 2

# elem_start = 64
# active_element = range(elem_start-delta,  elem_start+delta)
# active_element =  elem_start+delta
# apod[active_element] = 1.0  # Set the last element to 1.0 for apodization
# apodization = tx.set_apodization(apod)
# # tx.show()

# Example field points: center line# Wrap in TorchField
Matrix_field = pyfield.PyField(tx)
t_np, h_np, events_np = Matrix_field.spatial_impulse_response(field_info_mm, return_all=True)

torch.cuda.empty_cache()
model = TorchField(tx, device=device)
t_th, h_th, events_th = model.spatial_impulse_response(field_info_mm, batch_size=1000, return_all=True)


model2 = TorchFieldv2(tx, device=device)
t_th2, h_th2, events_th2 = model2.spatial_impulse_response(field_info_mm, batch_size=1000, return_all=True)

plt.figure(figsize=(15, 10))

# Create the first plot
ax1 = plt.gca()  # Get the current axes
ax1.plot(t_th.detach().cpu().numpy(), h_th.detach().cpu().numpy(), 'o-', label='Torch1', color='red')
ax1.plot(t_th2.detach().cpu().numpy(), h_th2.detach().cpu().numpy(), 'd--', label='Torch2', color='k')
ax1.set_ylabel('Torch Values', color='red')
ax1.tick_params(axis='y', labelcolor='red')
ax1.set_xlabel('Time (t)')
ax1.legend(loc='upper left')
plt.ylim([np.min(h_np)*1, np.max(h_np)*1.2])
# for i in range(events_np.shape[1]): 
 
# Create the second plot with a secondary y-axis
ax2 = ax1.twinx()
ax2.plot(t_np, h_np, 's-', label='NumPy', color='blue')
ax2.set_ylabel('NumPy Values', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
ax2.legend(loc='upper right')

selected_times = (events_th[0,active_element*2,:4]/model.time_sec_to_unit).detach().cpu().numpy()
ax2.vlines(selected_times, 
        ymin=np.min(h_np), ymax=np.max(h_np), colors = 'b', linestyle=':', label='Events NumPy')

t0 = t_th.detach().cpu().numpy().min()
tN = t_th.detach().cpu().numpy().max()
plt.xlim([t0*1.01, (t0*1.20)])
plt.ylim([np.min(h_np)*0.95, np.max(h_np)*1.2])
plt.title('Comparison of NumPy and Torch Outputs')
plt.show()
# Out:
# LinearArrayTransducer initialized in 0.0027 seconds.
# Field info: {'x_extent': [0, 0], 'y_extent': [0, 0], 'z_extent': [np.int64(8), np.int64(8)], 'dx': 0, 'dy': 0, 'dz': 0}
# Computing SIR for 1 points and 256 patches...
# Events patch - field points computed in: 0.0010 seconds.
# Accumulation of events elapsed in: 0.0000 seconds.
# Time range: 5.13 us to 9.09 us
# max delay: 1.70 us, vs real 0.00 us
# Computing SIR: 100%|██████████| 1/1 [00:00<00:00, 120.36batch/s]
# Spatial impulse response computed in 0.01 seconds with batch size 1000.
# tensor([[0.0000, 0.0000, 0.0080]], device='cuda:0')
# Time range: 5.13 us to 9.09 us
# Computing SIR: 100%|██████████| 1/1 [00:00<00:00, 47.96batch/s]
# Spatial impulse response computed in 0.03 seconds with batch size 1000.

# %%
use_cuda = False  # Set to False if you want to run on CPU
device_number = 0  # if you have multiple GPUs
if torch.cuda.is_available() and use_cuda:
    print(f"Using GPU: {torch.cuda.get_device_name(device_number)}")
    device = torch.device(f"cuda:{device_number}")
else:
    print("Running on CPU. May be slow.")
    device = torch.device("cpu")

domino = pysonogen.transducers.Domino()
FoverD = 1 
# Focalization spot
focus_mm = np.array([0, 0, 8])  # mm [x, y, z]
field_info_mm = {
    "x_extent" : [-0.5, 0.5],
    "y_extent" : [-0.75, 0.75],
    "z_extent" : [7, 9],
    "dx" : 0.025,
    "dy" : 0.025,
    "dz" : 0.02,
}

domino.compute_apodization(focus_mm=focus_mm, F_over_D=1, plot = True)
domino.compute_delays(focus_mm=focus_mm, plot=True)

dominofield = pyfield.PyField(domino)

pr1, x1, y1, z1 = dominofield.compute_pressure_field(field_info_mm, normalize = False, inplace = False)
pysonogen.plot_field_planes(pr1,
                               x1, y1, z1, interpolation = None)

# --------------------- TORCH FIELD ---------------------
del pr3, x3, y3, z3
torch.cuda.empty_cache()
dominomodel = TorchField(domino, device=device)
pr2, x2, y2, z2 = dominomodel.examine_bottleneck(field_info_mm, batch_size=4096, normalize = False)
pysonogen.plot_field_planes(pr2.detach().cpu().numpy(),
                             x2.detach().cpu().numpy(), y2.detach().cpu().numpy(),
                             z2.detach().cpu().numpy(), interpolation = None)

torch.cuda.empty_cache()
del pr2, x2, y2, z2

dominomodel2 = TorchFieldv2(domino, device=device)
pr3, x3, y3, z3 = dominomodel2.examine_bottleneck(field_info_mm, batch_size=4096, normalize = False)
pysonogen.plot_field_planes(pr3.detach().cpu().numpy(),
                             x3.detach().cpu().numpy(), y3.detach().cpu().numpy(),
                             z3.detach().cpu().numpy(), interpolation = None)
# Out:
# Running on CPU. May be slow.
# LinearArrayTransducer initialized in 0.0148 seconds.
# ...
# Computing SIR for 252601 points and 1280 patches...
# Events patch - field points computed in: 3.3223 seconds.
# Accumulation of events elapsed in: 77.0749 seconds.
# Looking for fc: 12500000.0 Hz, found : 12328767.123287672 Hz, in 2.11 seconds.
# Pressure field computed in: 1753111040.0000 seconds.
# Computing field for 252601 points and 1280 patches, WITHOUT gradients in cpu.
# Time range: 4.46 us to 9.44 us
# max delay: 1.70 us, vs real 1.70 us
# Computing SIR: 100%|██████████| 62/62 [00:27<00:00,  2.29batch/s]
# Spatial impulse response computed in 28.67 seconds with batch size 4096.
# Looking for fc: 12500000.0 Hz, found : 12431078.0 Hz, in 0.76 seconds.
# Pressure field computed in: 30.6465 seconds, using cpu.
# ------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# ...

# %%
# plotter, vol_mesh = pysonogen.plot_pressure_field(pr2.detach().cpu().numpy(),
#                              x2.detach().cpu().numpy(), y2.detach().cpu().numpy(),
#                              z2.detach().cpu().numpy(), notebook=False)

# plotter.show()

# %% [markdown]
# ## 4.2. Initialization of the model

# %% [markdown]
# ## 4.2. Optimization

# %% [markdown]
# ### 4.3. Create Target

# %%
folder = r'..\pressure_fields'
filename = r'/target_inverse.npz'

# %%
# %matplotlib widget

define_target_matrix= False

if define_target_matrix:
    matrix_size = 55
    target_matrix = np.zeros((matrix_size, matrix_size), dtype=int)

    fig, ax = plt.subplots(figsize=(8, 8))
    im = ax.imshow(target_matrix, cmap='gray_r', vmin=0, vmax=1)
    ax.set_title("Click to toggle elements (1=target, 0=off)")
    plt.xlabel("X")
    plt.ylabel("Y")

    def onclick(event):
        if event.inaxes == ax:
            x, y = int(round(event.xdata)), int(round(event.ydata))
            if 0 <= x < matrix_size and 0 <= y < matrix_size:
                target_matrix[y, x] = 1 - target_matrix[y, x]
                im.set_data(target_matrix)
                fig.canvas.draw_idle()

    cid = fig.canvas.mpl_connect('button_press_event', onclick)
    plt.show()
    
    plt.close(fig)
    np.savez_compressed(folder + filename,
                    target=target_matrix)
    print(f"Saved field to {folder + filename}")

# %%
# %matplotlib inline

target_matrix = np.load(folder + filename)['target']

print(target_matrix.shape) 
plt.figure(figsize=(5, 5))
plt.imshow(target_matrix, extent=[1, 55, 1, 55], cmap='gray_r', vmin=0, vmax=1)
plt.show()
plt.close()
# Out:
# (55, 55)

# %%
y_target = torch.tensor(target_matrix, dtype=torch.float32, device=device)

torch.cuda.empty_cache()
Matrix_torch = TorchField(Zeus_Matrix, device=device)
loss_fn = torch.nn.MSELoss()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 y_target = torch.tensor(target_matrix, dtype=torch.float32, device=device)
#       3 torch.cuda.empty_cache()
# ----> 4 Matrix_torch = TorchField(Zeus_Matrix, device=device)
#       5 loss_fn = torch.nn.MSELoss()
#
# NameError: name 'Zeus_Matrix' is not defined

# %%
import time
from tqdm import tqdm
# Decide number of iterations and learning rate
num_epoch = 10

# Initialize the optimizer
learning_rate = 1e-2

optimizer = torch.optim.Adam(
    Matrix_torch.parameters(), 
    lr=learning_rate
)

t0 = time.time()        
loss_vec = np.zeros(num_epoch+1)

for epoch in tqdm(range(num_epoch+1), unit='epoch', desc="Training Progress"):

    # 1) Zero the gradients
    optimizer.zero_grad() 
    
    # 2) Forward pass
    pr, x, y, z = Matrix_torch(field_matrix_mm, batch_size=512, training=True)
    y_pred = focalization_plane(pr, threshold=0.5)

    # 3) Compute the loss
    loss = loss_fn(y_target, y_pred)
    
    # 4) Backward pass
    loss.backward()

    # 5) Update the parameters
    optimizer.step()

    # 6) Store loss
    loss_vec = loss.item()
t1 = time.time()
print(f'Computation took {t1-t0:.1f} seconds.')
# Out:
# Training Progress:   0%|          | 0/11 [00:00<?, ?epoch/s]
# Computing field for 15125 points and 12100 patches in cuda:0. Mode: Training.
# ...
# Training Progress:   0%|          | 0/11 [00:15<?, ?epoch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 24
#      21 optimizer.zero_grad()
#      23 # 2) Forward pass
# ---> 24 pr, x, y, z = Matrix_torch(field_matrix_mm, batch_size=512, training=True)
#      25 y_pred = focalization_plane(pr, threshold=0.5)
#      27 # 3) Compute the loss
#
# File c:\Users\INSERM\Documents\Esteban\PySonoGen\.venv\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# ...
